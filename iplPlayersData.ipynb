# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from wordcloud import WordCloud

# %%
sns.set_context('poster',font_scale=1)
sns.set_style('ticks')

# %%
Batsmen = pd.read_csv(r'C:\Users\User\Desktop\Python Data\most_runs_average_strikerate.csv')
Teamwise = pd.read_csv(r'C:\Users\User\Desktop\Python Data\teamwise_home_and_away.csv')

# %%
Batsmen
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate
# 0           V Kohli        5426  152           4111  35.697368  131.987351
# 1          SK Raina        5386  160           3916  33.662500  137.538304
# 2         RG Sharma        4902  161           3742  30.447205  130.999466
# 3         DA Warner        4717  114           3292  41.377193  143.286756
# 4          S Dhawan        4601  137           3665  33.583942  125.538881
# ..              ...         ...  ...            ...        ...         ...
# 511        ND Doshi           0    1             13   0.000000    0.000000
# 512         J Denly           0    1              1   0.000000    0.000000
# 513         S Ladda           0    2              9   0.000000    0.000000
# 514  V Pratap Singh           0    1              1   0.000000    0.000000
# 515       S Kaushik           0    1              1   0.000000    0.000000
#
# [516 rows x 6 columns]

# %%
Batsmen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batsman        516 non-null    object
#  1   total_runs     516 non-null    int64
#  2   out            516 non-null    int64
#  3   numberofballs  516 non-null    int64
#  4   average        482 non-null    float64
#  5   strikerate     516 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 24.3+ KB

# %%
Batsmen[['batsman','average']]
# Out:
#             batsman    average
# 0           V Kohli  35.697368
# 1          SK Raina  33.662500
# 2         RG Sharma  30.447205
# 3         DA Warner  41.377193
# 4          S Dhawan  33.583942
# ..              ...        ...
# 511        ND Doshi   0.000000
# 512         J Denly   0.000000
# 513         S Ladda   0.000000
# 514  V Pratap Singh   0.000000
# 515       S Kaushik   0.000000
#
# [516 rows x 2 columns]

# %%
Batsmen[Batsmen['numberofballs']>1000]
# Out:
#              batsman  total_runs  out  numberofballs    average  strikerate
# 0            V Kohli        5426  152           4111  35.697368  131.987351
# 1           SK Raina        5386  160           3916  33.662500  137.538304
# 2          RG Sharma        4902  161           3742  30.447205  130.999466
# 3          DA Warner        4717  114           3292  41.377193  143.286756
# 4           S Dhawan        4601  137           3665  33.583942  125.538881
# 5           CH Gayle        4525  110           2972  41.136364  152.254374
# 6           MS Dhoni        4450  118           3206  37.711864  138.802246
# 7         RV Uthappa        4420  156           3381  28.333333  130.730553
# 8     AB de Villiers        4414  104           2902  42.442308  152.101999
# 9          G Gambhir        4219  134           3400  31.485075  124.088235
# 10         AM Rahane        3834  117           3133  32.769231  122.374721
# ...

# %%
Batsmen[Batsmen['strikerate']== Batsmen['strikerate'].max()]
# Out:
#              batsman  total_runs  out  numberofballs  average  strikerate
# 443       B Stanlake           5    0              2      NaN       250.0
# 449  KMDN Kulasekara           5    0              2      NaN       250.0

# %%
Batsmen[Batsmen['average']==Batsmen['average'].max()]
# Out:
#            batsman  total_runs  out  numberofballs  average  strikerate
# 243  Iqbal Abdulla          88    1             83     88.0  106.024096

# %%
Batsmen[Batsmen['total_runs']==Batsmen['total_runs'].max()]
# Out:
#    batsman  total_runs  out  numberofballs    average  strikerate
# 0  V Kohli        5426  152           4111  35.697368  131.987351

# %%
Batsmen.head()
# Out:
#      batsman  total_runs  out  numberofballs    average  strikerate
# 0    V Kohli        5426  152           4111  35.697368  131.987351
# 1   SK Raina        5386  160           3916  33.662500  137.538304
# 2  RG Sharma        4902  161           3742  30.447205  130.999466
# 3  DA Warner        4717  114           3292  41.377193  143.286756
# 4   S Dhawan        4601  137           3665  33.583942  125.538881

# %%
Teamwise['total_matches'] = Teamwise['home_matches']+Teamwise['away_matches']

# %%
Teamwise['total_win-percentage'] = (Teamwise['home_win_percentage']+Teamwise['away_win_percentage'])/2

# %%
Teamwise['total_wins'] = Teamwise['home_wins']+Teamwise['away_wins']

# %%
Teamwise
# Out:
#                            team  home_wins  away_wins  home_matches  \
# 0        Rising Pune Supergiant          5          5             8
# 1                Mumbai Indians         58         51           101
# 2           Chennai Super Kings         51         49            89
# 3                Delhi Capitals          3          7             6
# 4           Sunrisers Hyderabad         30         28            63
# 5              Rajasthan Royals         29         46            67
# 6               Deccan Chargers         18         11            43
# 7               Kings XI Punjab         38         44            91
# 8   Royal Challengers Bangalore         35         49            85
# 9         Kolkata Knight Riders         34         58            83
# 10             Delhi Daredevils         25         42            72
# 11                Pune Warriors          6          6            20
# 12         Kochi Tuskers Kerala          2          4             7
# ...

# %%
Teamwise[Teamwise['away_wins']==Teamwise['away_wins'].max()]
# Out:
#                     team  home_wins  away_wins  home_matches  away_matches  \
# 9  Kolkata Knight Riders         34         58            83            95
#
#    home_win_percentage  away_win_percentage  total_matches  \
# 9            40.963855            61.052632            178
#
#    total_win-percentage  total_wins
# 9             51.008244          92

# %%
Teamwise[Teamwise['total_matches']>20]['total_win-percentage'].max()
# Out:
# 61.31835205992509

# %%
Teamwise[Teamwise['total_wins']==Teamwise['total_wins'].max()]
# Out:
#              team  home_wins  away_wins  home_matches  away_matches  \
# 1  Mumbai Indians         58         51           101            86
#
#    home_win_percentage  away_win_percentage  total_matches  \
# 1            57.425743            59.302326            187
#
#    total_win-percentage  total_wins
# 1             58.364034         109

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=Teamwise['total_wins'],y=Teamwise['team'],palette="Blues_d")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(60,13)
ax.plot(Teamwise['team'], Teamwise['away_win_percentage'], '-b', label='Away Win Percentage')
ax.plot(Teamwise['team'], Teamwise['home_win_percentage'], '--r', label='home Win Percentage')
#ax.axis('equal')
leg = ax.legend();

# %%
plt.figure(figsize=(15,10))
sns.barplot(Teamwise['total_win-percentage'],Teamwise['team'],palette="twilight_shifted")

# %%
Batsmen
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate
# 0           V Kohli        5426  152           4111  35.697368  131.987351
# 1          SK Raina        5386  160           3916  33.662500  137.538304
# 2         RG Sharma        4902  161           3742  30.447205  130.999466
# 3         DA Warner        4717  114           3292  41.377193  143.286756
# 4          S Dhawan        4601  137           3665  33.583942  125.538881
# ..              ...         ...  ...            ...        ...         ...
# 511        ND Doshi           0    1             13   0.000000    0.000000
# 512         J Denly           0    1              1   0.000000    0.000000
# 513         S Ladda           0    2              9   0.000000    0.000000
# 514  V Pratap Singh           0    1              1   0.000000    0.000000
# 515       S Kaushik           0    1              1   0.000000    0.000000
#
# [516 rows x 6 columns]

# %%
TopAvg = Batsmen[Batsmen['numberofballs']>2000]

# %%
TopAvg
# Out:
#            batsman  total_runs  out  numberofballs    average  strikerate
# 0          V Kohli        5426  152           4111  35.697368  131.987351
# 1         SK Raina        5386  160           3916  33.662500  137.538304
# 2        RG Sharma        4902  161           3742  30.447205  130.999466
# 3        DA Warner        4717  114           3292  41.377193  143.286756
# 4         S Dhawan        4601  137           3665  33.583942  125.538881
# 5         CH Gayle        4525  110           2972  41.136364  152.254374
# 6         MS Dhoni        4450  118           3206  37.711864  138.802246
# 7       RV Uthappa        4420  156           3381  28.333333  130.730553
# 8   AB de Villiers        4414  104           2902  42.442308  152.101999
# 9        G Gambhir        4219  134           3400  31.485075  124.088235
# 10       AM Rahane        3834  117           3133  32.769231  122.374721
# 11      KD Karthik        3669  138           2813  26.586957  130.430146
# ...

# %%
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.figure(figsize=(45,15))
sns.barplot(TopAvg['batsman'],TopAvg['average'],palette='viridis_r')

# %%
plt.figure(figsize=(45,15))
sns.lineplot(TopAvg['batsman'],TopAvg['strikerate'],legend='brief',lw='3')

# %%
plt.figure(figsize=(15,8))
sns.kdeplot(TopAvg['average'],TopAvg['numberofballs'])

# %%
sns.jointplot(TopAvg['average'],TopAvg['strikerate'],kind="reg",color='green')

# %%
sns.pairplot(TopAvg, palette="husl")

# %%
c1 = ''.join(str(Batsmen['batsman'].values))
from wordcloud import WordCloud
plt.figure(figsize=(10,7))
wordcloud = WordCloud(max_font_size=None, background_color='white', collocations=False,
                      width=1000, height=1000).generate(c1)
plt.imshow(wordcloud, interpolation="spline16")
plt.axis("off")
# Out:
# (-0.5, 999.5, 999.5, -0.5)
